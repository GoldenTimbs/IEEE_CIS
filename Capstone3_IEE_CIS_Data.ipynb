# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from scipy import stats
from scipy.stats import chi2_contingency 
import matplotlib.pyplot as plt

# %%
transactions = pd.read_csv('C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\train_transaction.csv')
transactions
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987000        0          86400           68.50         W
# 1             2987001        0          86401           29.00         W
# 2             2987002        0          86469           59.00         W
# 3             2987003        0          86499           50.00         W
# 4             2987004        0          86506           50.00         H
# ...               ...      ...            ...             ...       ...
# 590535        3577535        0       15811047           49.00         W
# 590536        3577536        0       15811049           39.50         W
# 590537        3577537        0       15811079           30.95         W
# 590538        3577538        0       15811088          117.00         W
# 590539        3577539        0       15811131          279.95         W
#
#         card1  card2  card3       card4  card5  ... V330  V331  V332  V333  \
# ...

# %%
transactions.drop(columns=['V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V21','V22','V23','V24','V25','V26','V27','V28','V29','V30','V31','V32','V33','V34','V35','V36','V37','V38','V39','V40','V41','V42','V43','V44','V45','V46','V47','V48','V49','V50','V51','V52','V53','V54','V55','V56','V57','V58','V59','V60','V61','V62','V63','V64','V65','V66','V67','V68','V69','V70','V71','V72','V73','V74','V75','V76','V77','V78','V79','V80','V81','V82','V83','V84','V85','V86','V87','V88','V89','V90','V91','V92','V93','V94','V95','V96','V97','V98','V99','V100','V101','V102','V103','V104','V105','V106','V107','V108','V109','V110','V111','V112','V113','V114','V115','V116','V117','V118','V119','V120','V121','V122','V123','V124','V125','V126','V127','V128','V129','V130','V131','V132','V133','V134','V135','V136','V137','V138','V139','V140','V141','V142','V143','V144','V145','V146','V147','V148','V149','V150','V151','V152','V153','V154','V155','V156','V157','V158','V159','V160','V161','V162','V163','V164','V165','V166','V167','V168','V169','V170','V171','V172','V173','V174','V175','V176','V177','V178','V179','V180','V181','V182','V183','V184','V185','V186','V187','V188','V189','V190','V191','V192','V193','V194','V195','V196','V197','V198','V199','V200','V201','V202','V203','V204','V205','V206','V207','V208','V209','V210','V211','V212','V213','V214','V215','V216','V217','V218','V219','V220','V221','V222','V223','V224','V225','V226','V227','V228','V229','V230','V231','V232','V233','V234','V235','V236','V237','V238','V239','V240','V241','V242','V243','V244','V245','V246','V247','V248','V249','V250','V251','V252','V253','V254','V255','V256','V257','V258','V259','V260','V261','V262','V263','V264','V265','V266','V267','V268','V269','V270','V271','V272','V273','V274','V275','V276','V277','V278','V279','V280','V281','V282','V283','V284','V285','V286','V287','V288','V289','V290','V291','V292','V293','V294','V295','V296','V297','V298','V299','V300','V301','V302','V303','V304','V305','V306','V307','V308','V309','V310','V311','V312','V313','V314','V315','V316','V317','V318','V319','V320','V321','V322','V323','V324','V325','V326','V327','V328','V329','V330','V331','V332','V333','V334','V335','V336','V337','V338','V339'], inplace=True)

# %%
transactions
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987000        0          86400           68.50         W
# 1             2987001        0          86401           29.00         W
# 2             2987002        0          86469           59.00         W
# 3             2987003        0          86499           50.00         W
# 4             2987004        0          86506           50.00         H
# ...               ...      ...            ...             ...       ...
# 590535        3577535        0       15811047           49.00         W
# 590536        3577536        0       15811049           39.50         W
# 590537        3577537        0       15811079           30.95         W
# 590538        3577538        0       15811088          117.00         W
# 590539        3577539        0       15811131          279.95         W
#
#         card1  card2  card3       card4  card5  ...    D15   M1   M2   M3  \
# ...

# %%
transactions.groupby('card4')['isFraud'].mean()
# Out:
# card4
# american express    0.028698
# discover            0.077282
# mastercard          0.034331
# visa                0.034756
# Name: isFraud, dtype: float64

# %%
observed = pd.crosstab(transactions['card4'],transactions['isFraud'])
print(observed)
# Out:
# isFraud                0      1
# card4
# american express    8089    239
# discover            6137    514
# mastercard        182721   6496
# visa              371394  13373

# %%
observed.values
# Out:
# array([[  8089,    239],
#        [  6137,    514],
#        [182721,   6496],
#        [371394,  13373]], dtype=int64)

# %%
expected = stats.chi2_contingency(observed)

# %%
expected
# Out:
# (364.87413919008776,
#  8.969833608323728e-79,
#  3,
#  array([[8.03640271e+03, 2.91597292e+02],
#         [6.41812133e+03, 2.32878673e+02],
#         [1.82591740e+05, 6.62525995e+03],
#         [3.71294736e+05, 1.34722641e+04]]))

# %%
chi2, p, dof, expected = chi2_contingency(observed.values)
print(f'The test statistic is {chi2}. \nThe p value is {p}.')
# Out:
# The test statistic is 364.87413919008776.
# The p value is 8.969833608323728e-79.

# %%
sns.distplot(random.chisquare(df=3, size=1000), hist=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-a98d4030388d> in <module>
# ----> 1 sns.distplot(random.chisquare(df=3, size=1000), hist=False)
#       2 plt.show()
#
# NameError: name 'random' is not defined

# %%
#transactions.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\updated_transactions.csv', index = False)

# %%
visa = transactions.loc[:, ['TransactionAmt', 'card4']]
visa
# Out:
#         TransactionAmt       card4
# 0                68.50    discover
# 1                29.00  mastercard
# 2                59.00        visa
# 3                50.00  mastercard
# 4                50.00  mastercard
# ...                ...         ...
# 590535           49.00        visa
# 590536           39.50  mastercard
# 590537           30.95  mastercard
# 590538          117.00  mastercard
# 590539          279.95  mastercard
#
# [590540 rows x 2 columns]

# %%
visa_nfraud = transactions.loc[(transactions['card4'] == 'visa') & (transactions['isFraud'] == 0)]
visa_nfraud
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 2             2987002        0          86469           59.00         W
# 5             2987005        0          86510           49.00         W
# 6             2987006        0          86522          159.00         W
# 7             2987007        0          86529          422.50         W
# 8             2987008        0          86535           15.00         H
# ...               ...      ...            ...             ...       ...
# 590525        3577525        0       15810866           57.95         W
# 590527        3577527        0       15810883          189.95         W
# 590531        3577531        0       15810935          400.00         R
# 590533        3577533        0       15811029          107.95         W
# 590535        3577535        0       15811047           49.00         W
#
#         card1  card2  card3 card4  card5  ...    D15   M1   M2   M3   M4   M5  \
# ...

# %%
visa_fraud = transactions.loc[(transactions['card4'] == 'visa') & (transactions['isFraud'] == 1)]
visa_fraud
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 203           2987203        1          89760         445.000         W
# 240           2987240        1          90193          37.098         C
# 243           2987243        1          90246          37.098         C
# 245           2987245        1          90295          37.098         C
# 288           2987288        1          90986         155.521         C
# ...               ...      ...            ...             ...       ...
# 590350        3577350        1       15807118          59.000         W
# 590354        3577354        1       15807171         125.665         C
# 590361        3577361        1       15807368        1224.000         W
# 590372        3577372        1       15807758         117.000         W
# 590526        3577526        1       15810876         250.000         R
#
#         card1  card2  card3 card4  card5  ...    D15   M1   M2   M3   M4   M5  \
# ...

# %%
mc_nfraud = transactions.loc[(transactions['card4'] == 'mastercard') & (transactions['isFraud'] == 0)]
mc_nfraud
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 1             2987001        0          86401          29.000         W
# 3             2987003        0          86499          50.000         W
# 4             2987004        0          86506          50.000         H
# 9             2987009        0          86536         117.000         W
# 10            2987010        0          86549          75.887         C
# ...               ...      ...            ...             ...       ...
# 590534        3577534        0       15811030          67.505         C
# 590536        3577536        0       15811049          39.500         W
# 590537        3577537        0       15811079          30.950         W
# 590538        3577538        0       15811088         117.000         W
# 590539        3577539        0       15811131         279.950         W
#
#         card1  card2  card3       card4  card5  ...    D15   M1   M2   M3  \
# ...

# %%
mc_fraud = transactions.loc[(transactions['card4'] == 'mastercard') & (transactions['isFraud'] == 1)]
mc_fraud
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 367           2987367        1          92350         225.000         R
# 405           2987405        1          92999          90.570         C
# 630           2987630        1          97843          12.326         C
# 683           2987683        1          99584         124.344         C
# 779           2987779        1         102154          10.000         S
# ...               ...      ...            ...             ...       ...
# 590103        3577103        1       15802102          38.414         C
# 590308        3577308        1       15806122         934.000         W
# 590327        3577327        1       15806478         934.000         W
# 590351        3577351        1       15807131         125.665         C
# 590364        3577364        1       15807516          69.964         C
#
#         card1  card2  card3       card4  card5  ...   D15   M1   M2   M3   M4  \
# ...

# %%
disc_nfraud = transactions.loc[(transactions['card4'] == 'discover') & (transactions['isFraud'] == 0)]
disc_nfraud
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987000        0          86400           68.50         W
# 135           2987135        0          88671         3000.00         W
# 223           2987223        0          89948           54.00         W
# 360           2987360        0          92221          226.00         W
# 451           2987451        0          93931           59.00         W
# ...               ...      ...            ...             ...       ...
# 589811        3576811        0       15795887          179.97         W
# 589935        3576935        0       15798539          226.00         W
# 589946        3576946        0       15798730           49.00         W
# 590118        3577118        0       15802377           54.50         W
# 590490        3577490        0       15810157          379.95         W
#
#         card1  card2  card3     card4  card5  ...    D15   M1   M2   M3   M4  \
# ...

# %%
disc_fraud = transactions.loc[(transactions['card4'] == 'discover') & (transactions['isFraud'] == 1)]
disc_fraud
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 2598          2989598        1         147621          100.00         S
# 8629          2995629        1         255754          100.00         S
# 8769          2995769        1         257703           49.00         W
# 10339         2997339        1         319679          150.00         H
# 11855         2998855        1         342294          117.00         W
# ...               ...      ...            ...             ...       ...
# 583055        3570055        1       15595541           30.00         S
# 584743        3571743        1       15631810         2480.06         W
# 586825        3573825        1       15706107          213.00         W
# 588607        3575607        1       15770587          100.00         S
# 588854        3575854        1       15777176          974.00         W
#
#         card1  card2  card3     card4  card5  ...  D15   M1   M2   M3   M4  \
# ...

# %%
transactions.groupby('TransactionID')['TransactionAmt'].agg('mean')
# Out:
# TransactionID
# 2987000     68.50
# 2987001     29.00
# 2987002     59.00
# 2987003     50.00
# 2987004     50.00
#             ...
# 3577535     49.00
# 3577536     39.50
# 3577537     30.95
# 3577538    117.00
# 3577539    279.95
# Name: TransactionAmt, Length: 590540, dtype: float64

# %%
identity = pd.read_csv('C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\train_identity.csv')
identity
# Out:
#         TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  \
# 0             2987004    0.0   70787.0    NaN    NaN    NaN    NaN    NaN
# 1             2987008   -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN
# 2             2987010   -5.0  191631.0    0.0    0.0    0.0    0.0    NaN
# 3             2987011   -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN
# 4             2987016    0.0    7460.0    0.0    0.0    1.0    0.0    NaN
# ...               ...    ...       ...    ...    ...    ...    ...    ...
# 144228        3577521  -15.0  145955.0    0.0    0.0    0.0    0.0    NaN
# 144229        3577526   -5.0  172059.0    NaN    NaN    1.0   -5.0    NaN
# 144230        3577529  -20.0  632381.0    NaN    NaN   -1.0  -36.0    NaN
# 144231        3577531   -5.0   55528.0    0.0    0.0    0.0   -7.0    NaN
# 144232        3577534  -45.0  339406.0    NaN    NaN  -10.0 -100.0    NaN
#
#         id_08  id_09  ...                    id_31  id_32      id_33  \
# ...

# %%
joined_it = pd.merge(transactions, identity, on='TransactionID', how='inner')
joined_it
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987004        0          86506          50.000         H
# 1             2987008        0          86535          15.000         H
# 2             2987010        0          86549          75.887         C
# 3             2987011        0          86555          16.495         C
# 4             2987016        0          86620          30.000         H
# ...               ...      ...            ...             ...       ...
# 144228        3577521        0       15810802          48.877         C
# 144229        3577526        1       15810876         250.000         R
# 144230        3577529        0       15810912          73.838         C
# 144231        3577531        0       15810935         400.000         R
# 144232        3577534        0       15811030          67.505         C
#
#         card1  card2  card3       card4  card5  ...                    id_31  \
# ...

# %%
visa_f = joined_it.loc[(joined_it['card4'] == 'visa') & (joined_it['isFraud'] == 1)]
visa_f
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 52            2987240        1          90193          37.098         C
# 53            2987243        1          90246          37.098         C
# 54            2987245        1          90295          37.098         C
# 69            2987288        1          90986         155.521         C
# 271           2987869        1         106603          83.380         C
# ...               ...      ...            ...             ...       ...
# 144155        3577087        1       15801801          38.414         C
# 144164        3577147        1       15802899          38.414         C
# 144201        3577347        1       15807005         450.000         H
# 144203        3577354        1       15807171         125.665         C
# 144229        3577526        1       15810876         250.000         R
#
#         card1  card2  card3 card4  card5  ...                    id_31  id_32  \
# ...

# %%
#visa_f.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\visa_fraud.csv', index = False)

# %%
visa_nf = joined_it.loc[(joined_it['card4'] == 'visa') & (joined_it['isFraud'] == 0)]
visa_nf
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 1             2987008        0          86535          15.000         H
# 4             2987016        0          86620          30.000         H
# 6             2987022        0          86786          50.000         H
# 8             2987040        0          87209          75.887         C
# 9             2987048        0          87317          42.294         C
# ...               ...      ...            ...             ...       ...
# 144221        3577478        0       15809945          24.422         C
# 144222        3577486        0       15810107          41.315         C
# 144223        3577495        0       15810221         100.000         H
# 144227        3577509        0       15810491          28.527         C
# 144231        3577531        0       15810935         400.000         R
#
#         card1  card2  card3 card4  card5  ...                    id_31  id_32  \
# ...

# %%
#visa_nf.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\visa_nfraud.csv', index = False)

# %%
mastercard_f = joined_it.loc[(joined_it['card4'] == 'mastercard') & (joined_it['isFraud'] == 1)]
mastercard_f
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 86            2987367        1          92350         225.000         R
# 98            2987405        1          92999          90.570         C
# 185           2987630        1          97843          12.326         C
# 201           2987683        1          99584         124.344         C
# 235           2987779        1         102154          10.000         S
# ...               ...      ...            ...             ...       ...
# 144154        3577084        1       15801760          38.414         C
# 144156        3577092        1       15801846          38.414         C
# 144160        3577103        1       15802102          38.414         C
# 144202        3577351        1       15807131         125.665         C
# 144204        3577364        1       15807516          69.964         C
#
#         card1  card2  card3       card4  card5  ...                    id_31  \
# ...

# %%
#mastercard_f.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\mastercard_fraud.csv', index = False)

# %%
mastercard_nf = joined_it.loc[(joined_it['card4'] == 'mastercard') & (joined_it['isFraud'] == 0)]
mastercard_nf
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987004        0          86506          50.000         H
# 2             2987010        0          86549          75.887         C
# 3             2987011        0          86555          16.495         C
# 5             2987017        0          86668         100.000         H
# 10            2987049        0          87317           3.595         C
# ...               ...      ...            ...             ...       ...
# 144225        3577501        0       15810344          58.512         C
# 144226        3577506        0       15810402         200.000         H
# 144228        3577521        0       15810802          48.877         C
# 144230        3577529        0       15810912          73.838         C
# 144232        3577534        0       15811030          67.505         C
#
#         card1  card2  card3       card4  card5  ...                    id_31  \
# ...

# %%
#mastercard_nf.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\mastercard_nfraud.csv', index = False)

# %%
discover_f = joined_it.loc[(joined_it['card4'] == 'discover') & (joined_it['isFraud'] == 1)]
discover_f
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 519           2989598        1         147621           100.0         S
# 1778          2995629        1         255754           100.0         S
# 2264          2997339        1         319679           150.0         H
# 3704          3002976        1         430109           175.0         S
# 3709          3003014        1         430475           175.0         S
# ...               ...      ...            ...             ...       ...
# 142758        3569379        1       15550874            30.0         S
# 142765        3569467        1       15553135            30.0         S
# 142897        3570053        1       15595291            30.0         S
# 142898        3570055        1       15595541            30.0         S
# 143876        3575607        1       15770587           100.0         S
#
#         card1  card2  card3     card4  card5  ...                    id_31  \
# ...

# %%
#discover_f.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\discover_fraud.csv', index = False)

# %%
discover_nf = joined_it.loc[(joined_it['card4'] == 'discover') & (joined_it['isFraud'] == 0)]
discover_nf
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 193           2987648        0          98339            25.0         S
# 267           2987855        0         105877            75.0         H
# 361           2988667        0         137335            50.0         R
# 362           2988672        0         137422            50.0         R
# 363           2988678        0         137542            50.0         R
# ...               ...      ...            ...             ...       ...
# 143718        3574716        0       15723540           200.0         S
# 143749        3574915        0       15727727            75.0         H
# 143915        3575805        0       15776352           150.0         R
# 143969        3576096        0       15781980           100.0         R
# 143991        3576181        0       15783906            50.0         H
#
#         card1  card2  card3     card4  card5  ...                  id_31  \
# ...

# %%
#discover_nf.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\discover_nfraud.csv', index = False)

# %%
amex_f = joined_it.loc[(joined_it['card4'] == 'american express') & (joined_it['isFraud'] == 1)] 
amex_f
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 630           2990196        1         153263           225.0         R
# 631           2990200        1         153305           225.0         R
# 3585          3002413        1         422869           150.0         R
# 4101          3004339        1         468557           200.0         R
# 5581          3009041        1         579392           200.0         H
# ...               ...      ...            ...             ...       ...
# 139270        3550978        1       14939634            75.0         H
# 139406        3551737        1       14953518           100.0         R
# 143291        3572414        1       15646897           100.0         H
# 143708        3574676        1       15722797             5.0         S
# 144206        3577368        1       15807677           100.0         H
#
#         card1  card2  card3             card4  card5  ...  \
# ...

# %%
#amex_f.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\amex_fraud.csv', index = False)

# %%
amex_nf = joined_it.loc[(joined_it['card4'] == 'american express') & (joined_it['isFraud'] == 0)]
amex_nf
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 7             2987038        0          87172            25.0         S
# 27            2987119        0          88484           100.0         H
# 34            2987145        0          88805           100.0         R
# 71            2987311        0          91343            50.0         H
# 83            2987355        0          92158           500.0         R
# ...               ...      ...            ...             ...       ...
# 144117        3576894        0       15797682            40.0         S
# 144210        3577418        0       15808918           150.0         R
# 144213        3577442        0       15809393           100.0         R
# 144216        3577451        0       15809554           200.0         R
# 144217        3577465        0       15809790           250.0         R
#
#         card1  card2  card3             card4  card5  ...  \
# ...

# %%
#amex_nf.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\amex_nfraud.csv', index = False)

# %%
fraud_charges = pd.concat([visa_f,mastercard_f,discover_f,amex_f])
fraud_charges
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 52            2987240        1          90193          37.098         C
# 53            2987243        1          90246          37.098         C
# 54            2987245        1          90295          37.098         C
# 69            2987288        1          90986         155.521         C
# 271           2987869        1         106603          83.380         C
# ...               ...      ...            ...             ...       ...
# 139270        3550978        1       14939634          75.000         H
# 139406        3551737        1       14953518         100.000         R
# 143291        3572414        1       15646897         100.000         H
# 143708        3574676        1       15722797           5.000         S
# 144206        3577368        1       15807677         100.000         H
#
#         card1  card2  card3             card4  card5  ...  \
# ...

# %%
#fraud_charges.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\fraud_transactions.csv', index = False)

# %%
valid_charges = pd.concat([visa_nf,mastercard_nf,discover_nf,amex_nf])
valid_charges
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 1             2987008        0          86535          15.000         H
# 4             2987016        0          86620          30.000         H
# 6             2987022        0          86786          50.000         H
# 8             2987040        0          87209          75.887         C
# 9             2987048        0          87317          42.294         C
# ...               ...      ...            ...             ...       ...
# 144117        3576894        0       15797682          40.000         S
# 144210        3577418        0       15808918         150.000         R
# 144213        3577442        0       15809393         100.000         R
# 144216        3577451        0       15809554         200.000         R
# 144217        3577465        0       15809790         250.000         R
#
#         card1  card2  card3             card4  card5  ...  \
# ...

# %%
#valid_charges.to_csv(r'C:\\Users\\Danny\\Desktop\\GITHUB\\capstone_3\\\valid_transactions.csv', index = False)
